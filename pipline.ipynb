# %%
import pandas as pd 
df=pd.read_csv('house_prices.csv',index_col='id')
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0          N     0    Average      7        1180
# 6414100192      7242     2.0          N     0    Average      7        2170
# 5631500400     10000     1.0          N     0    Average      6         770
# 2487200875      5000     1.0          N     0  Very Good      7        1050
# 1954400510      8080     1.0          N     0    Average      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 2487200875           1360        5000
# 1954400510           1800        7503

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront        object
# view               int64
# condition         object
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
y=df.price
X=df.drop('price',axis=1)
X_train_full,X_valid_full,y_train,y_valid=train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=42)

# %%
cat=X_train_full.select_dtypes(include=['object']).columns.tolist()

# %%
cat
# Out:
# ['date', 'waterfront', 'condition']

# %%
cardi=[col for col in cat if X_train_full[col].nunique()<10]

# %%
cardi
# Out:
# ['waterfront', 'condition']

# %%
num=X_train_full.select_dtypes(exclude=['object']).columns.tolist()
num
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'view',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
cols=cardi+num

# %%
X_train=X_train_full[cols].copy()
X_valid=X_valid_full[cols].copy()

# %%
X_train.shape
# Out:
# (17290, 18)

# %%
df.shape
# Out:
# (21613, 20)

# %%
set(df)-set(X_train)
# Out:
# {'date', 'price'}

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#numerical preprocessing
numerical_transformer=SimpleImputer(strategy='constant')

#categorical preprocessing 
categorical_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
     ('onehot',OneHotEncoder(handle_unknown='ignore'))
])

#comine everything with ColumnTransformer
preprocessor=ColumnTransformer(
    transformers=[
        ('num',numerical_transformer,num),
        ('cat',categorical_transformer,cardi)
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', SimpleImputer(strategy='constant'),
#                                  ['bedrooms', 'bathrooms', 'sqft_living',
#                                   'sqft_lot', 'floors', 'view', 'grade',
#                                   'sqft_above', 'sqft_basement', 'yr_built',
#                                   'yr_renovated', 'zipcode', 'lat', 'long',
#                                   'sqft_living15', 'sqft_lot15']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['waterfront', 'condition'])])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
model=RandomForestRegressor(n_estimators=100, random_state=0)

my_pipeline=Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('model',model)

])

my_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='constant'),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'sqft_living', 'sqft_lot',
#                                                    'floors', 'view', 'grade',
#                                                    'sqft_above',
#                                                    'sqft_basement', 'yr_built',
#                                                    'yr_renovated', 'zipcode',
#                                                    'lat', 'long',
#                                                    'sqft_living15',
#                                                    'sqft_lot15']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['waterfront',
#                                                    'condition'])])),
#                 ('model', RandomForestRegressor(random_state=0))])

# %%
my_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='constant'),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'sqft_living', 'sqft_lot',
#                                                    'floors', 'view', 'grade',
#                                                    'sqft_above',
#                                                    'sqft_basement', 'yr_built',
#                                                    'yr_renovated', 'zipcode',
#                                                    'lat', 'long',
#                                                    'sqft_living15',
#                                                    'sqft_lot15']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['waterfront',
#                                                    'condition'])])),
#                 ('model', RandomForestRegressor(random_state=0))])

# %%
pred=my_pipeline.predict(X_valid)

# %%
MAE=mean_absolute_error(y_valid,pred)
print('mean absolute error:',MAE)
# Out:
# mean absolute error: 72880.51642680347
